# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tobbaco=pd.read_csv('datafile.csv')

# %%
pd.set_option("display.max_columns",None)

# %%
tobbaco.drop(tobbaco.iloc[:,13:58],inplace=True,axis=1)

# %%
tobbaco
# Out:
#                         State/UT   Area  Ever tobacco users (%)  \
# 0                          India  Total                    18.1
# 1                          India  Urban                    13.5
# 2                          India  Rural                    19.5
# 3    Andaman and Nicobar Islands  Total                    21.5
# 4    Andaman and Nicobar Islands  Urban                    13.3
# ..                           ...    ...                     ...
# 102                  Uttarakhand  Total                    31.4
# 103                  Uttarakhand  Urban                    39.5
# 104                  Uttarakhand  Rural                    28.2
# 105                  West Bengal  Total                    17.3
# 106                  West Bengal  Urban                    18.0
#
#      Current tobacco users (%)  Ever tobacco smokers (%)  \
# 0                          8.5                      11.0
# 1                          5.5                       8.1
# ...

# %%
tobbaco[tobbaco.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State/UT, Area, Ever tobacco users (%), Current tobacco users (%), Ever tobacco smokers (%), Current tobacco smokers (%), Ever cigarette users (%), Current cigarette users (%), Ever bidi users (%) , Current bidi users (%), Ever smokeless tobacco users (%), Current smokeless tobacco users (%), Ever users of  paan masala together with tobacco (%), Schools aware of the policy for displaying ‘tobacco-free school’ board  (%)]
# Index: []

# %%
tobbaco.drop_duplicates(inplace=True)

# %%
tobbaco.isnull().sum()
# Out:
# State/UT                                                                       0
# Area                                                                           0
# Ever tobacco users (%)                                                         0
# Current tobacco users (%)                                                      0
# Ever tobacco smokers (%)                                                       0
# Current tobacco smokers (%)                                                    0
# Ever cigarette users (%)                                                       0
# Current cigarette users (%)                                                    0
# Ever bidi users (%)                                                            0
# Current bidi users (%)                                                         0
# Ever smokeless tobacco users (%)                                               0
# Current smokeless tobacco users (%)                                            0
# ...

# %%
tobbaco.nunique()
# Out:
# State/UT                                                                       36
# Area                                                                            3
# Ever tobacco users (%)                                                         92
# Current tobacco users (%)                                                      75
# Ever tobacco smokers (%)                                                       85
# Current tobacco smokers (%)                                                    69
# Ever cigarette users (%)                                                       72
# Current cigarette users (%)                                                    58
# Ever bidi users (%)                                                            63
# Current bidi users (%)                                                         49
# Ever smokeless tobacco users (%)                                               90
# ...

# %%
tobbaco['State/UT'].unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haweli', 'Daman and Diu', 'Delhi',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
tobbaco.nlargest(5,"Current tobacco users (%)")
# Out:
#              State/UT   Area  Ever tobacco users (%)  \
# 11  Arunachal Pradesh  Rural                    75.7
# 70            Mizoram  Urban                    88.7
# 9   Arunachal Pradesh  Total                    63.1
# 69            Mizoram  Total                    89.7
# 71            Mizoram  Rural                    91.1
#
#     Current tobacco users (%)  Ever tobacco smokers (%)  \
# 11                       69.2                      67.2
# 70                       59.6                      81.9
# 9                        57.9                      59.2
# 69                       57.9                      83.0
# 71                       55.8                      84.5
#
#     Current tobacco smokers (%)  Ever cigarette users (%)  \
# 11                         59.6                      48.0
# 70                         44.5                      76.8
# 9                          53.5                      47.9
# 69                         43.6                      76.9
# ...

# %%
tobbaco.nsmallest(5,'Current tobacco users (%)')
# Out:
#             State/UT   Area  Ever tobacco users (%)  \
# 49         Karnataka  Urban                     0.1
# 7     Andhra Pradesh  Urban                     4.5
# 85         Rajasthan  Urban                     5.6
# 42  Himachal Pradesh  Total                    33.4
# 44  Himachal Pradesh  Rural                    36.3
#
#     Current tobacco users (%)  Ever tobacco smokers (%)  \
# 49                        0.0                       0.1
# 7                         0.7                       2.0
# 85                        0.7                       2.4
# 42                        1.0                       5.5
# 44                        1.0                       5.7
#
#     Current tobacco smokers (%)  Ever cigarette users (%)  \
# 49                          0.0                       0.0
# 7                           0.7                       1.2
# 85                          0.7                       1.7
# 42                          0.5                       1.3
# ...

# %%
plt.figure(figsize=(22,5))
plt.xticks(rotation=80)
tobbaco.boxplot()
# Out:
# <AxesSubplot:>

# %%
t1=tobbaco[tobbaco['Ever tobacco users (%)']<28]
t1.boxplot('Ever tobacco users (%)')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='State/UT',y='Ever tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Ever tobacco users (%)'>

# %%
sns.displot(tobbaco['Ever tobacco users (%)'],color='c',bins=20)

# %%
sns.distplot(tobbaco['Ever tobacco users (%)'],color='c',bins=20)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ever tobacco users (%)', ylabel='Density'>

# %%
sns.displot(tobbaco['Current tobacco smokers (%)'],color='c',bins=20)

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='State/UT',y='Current tobacco smokers (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Current tobacco smokers (%)'>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='State/UT',y='Ever cigarette users (%)',data=tobbaco,hue='Area')
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Ever cigarette users (%)'>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='State/UT',y='Current cigarette users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Current cigarette users (%)'>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='State/UT',y='Current smokeless tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Current smokeless tobacco users (%)'>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='Area',y='Current smokeless tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Current smokeless tobacco users (%)'>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='Area',y='Ever tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Ever tobacco users (%)'>

# %%
plt.figure(figsize=(22,8))
plt.xticks(rotation=80)
sns.barplot(x='Area',y='Current tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Current tobacco users (%)'>

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot('State/UT',data=tobbaco)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State/UT', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.countplot('Area',data=tobbaco)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Area', ylabel='count'>

# %%
plt.figure(figsize=(22,5))
plt.xticks(rotation=90)
sns.barplot(x='State/UT',y='Ever tobacco users (%)',data=tobbaco,hue='Area')
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Ever tobacco users (%)'>

# %%
plt.figure(figsize=(22,5))
plt.xticks(rotation=90)
sns.barplot(x='State/UT',y='Current tobacco users (%)',data=tobbaco,hue='Area')
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Current tobacco users (%)'>

# %%
plt.figure(figsize=(22,5))
plt.xticks(rotation=90)
sns.barplot(x='State/UT',y='Current cigarette users (%)',data=tobbaco,hue='Area')
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Current cigarette users (%)'>

# %%
plt.figure(figsize=(22,5))
plt.xticks(rotation=90)
sns.violinplot(x='Area',y='Current cigarette users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Current cigarette users (%)'>

# %%
plt.figure(figsize=(22,5))
plt.xticks(rotation=90)
sns.violinplot(x='Area',y='Ever tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Ever tobacco users (%)'>

# %%
plt.figure(figsize=(22,7))
sns.set_context('poster',font_scale=(0.9))
plt.style.use('seaborn')
plt.xticks(rotation=90)
sns.scatterplot(x='State/UT',y='Ever tobacco users (%)',data=tobbaco)
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Ever tobacco users (%)'>

# %%
sns.lmplot('Ever tobacco smokers (%)','Current tobacco users (%)',data=tobbaco)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('Ever tobacco smokers (%)','Current tobacco users (%)',hue='Area',data=tobbaco,palette='rainbow')
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,9))
plt.xticks(rotation=80)
sns.stripplot('Ever tobacco smokers (%)','Current tobacco smokers (%)',data=tobbaco)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ever tobacco smokers (%)', ylabel='Current tobacco smokers (%)'>

# %% [markdown]
# # Telangana State

# %%
t1=tobbaco[tobbaco['State/UT']=='Telangana']

# %%
t1.plot(kind='bar',y='Ever tobacco users (%)',color='c',grid=True)
# Out:
# <AxesSubplot:>

# %%
t1.plot(kind='scatter',x='State/UT',y='Current tobacco users (%)',color='g')
# Out:
# <AxesSubplot:xlabel='State/UT', ylabel='Current tobacco users (%)'>

# %%
t1.plot(kind='pie',y='Current tobacco smokers (%)',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='Current tobacco smokers (%)'>

# %%
t1.plot(kind='pie',y='Ever smokeless tobacco users (%)',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='Ever smokeless tobacco users (%)'>

# %%
t1
# Out:
#      State/UT   Area  Ever tobacco users (%)  Current tobacco users (%)  \
# 93  Telangana  Total                     9.4                        5.2
# 94  Telangana  Urban                     9.7                        5.0
# 95  Telangana  Rural                     9.1                        5.5
#
#     Ever tobacco smokers (%)  Current tobacco smokers (%)  \
# 93                       6.9                          4.0
# 94                       6.9                          3.8
# 95                       7.0                          4.3
#
#     Ever cigarette users (%)  Current cigarette users (%)  \
# 93                       3.8                          2.5
# 94                       3.5                          2.1
# 95                       4.2                          3.1
#
#     Ever bidi users (%)   Current bidi users (%)  \
# 93                   2.5                     1.1
# 94                   2.1                     1.0
# 95                   3.0                     1.2
#
# ...
